# %% [markdown]
# <a href="https://colab.research.google.com/github/TienLungSun/PyTorch-deep-learning/blob/main/2.3.%20Regression%20HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
if(torch.cuda.is_available()):
    device = torch.device("cuda")
    print(device, torch.cuda.get_device_name(0))
else:
    device= torch.device("cpu")
    print(device)
# Out:
# cuda Tesla K80

# %% [markdown]
# # Read csv data file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5fc4b4b6-cc89-49cf-8c22-24715b95b2ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5fc4b4b6-cc89-49cf-8c22-24715b95b2ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving energydata_complete.csv to energydata_complete.csv

# %%
fnameLst = list(uploaded.keys())
fname = fnameLst[0]
print(fname)
# Out:
# energydata_complete.csv

# %%
import pandas as pd
df=pd.read_csv(fname)

# %%
df.head(5)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
dfX = df[['lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
       'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
       'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
       'Visibility', 'Tdewpoint']]
dfY = df[['Appliances']]

# %%
numpyX = np.array(dfX.values)
numpyY = np.array(dfY.values)

# %%
print(numpyX.shape, numpyY.shape)
# Out:
# (19735, 25) (19735, 1)

# %% [markdown]
# # Build NN

# %% [markdown]
# # Run training-test one time

# %% [markdown]
# # Run training-test 20 times
